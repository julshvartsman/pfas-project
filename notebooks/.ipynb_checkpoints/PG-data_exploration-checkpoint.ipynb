# %%
import pandas as pd
import numpy as np

df = pd.read_parquet("processed/pfas_acs_zcta_month.parquet")

# %%
contain_pfas = df[df['any_detection']== True]
contain_pfas_by_zcta = contain_pfas.groupby('zcta')[['mean_result_ngL']].mean().sort_values(by='mean_result_ngL', ascending=False)
contain_pfas_by_zcta
# Out:
#        mean_result_ngL
# zcta
# 55071      1225.000000
# 44118       400.000000
# 55128       285.990556
# 96950       257.999126
# 85258       171.150000
# ...                ...
# 21213         3.000000
# 30917         3.000000
# 86404         3.000000
# 21214         3.000000
# 21051         3.000000
#
# [9670 rows x 1 columns]

# %%
max(df["n_contaminants"]) #only search for a maximum of 29 PFAS chemicals though there
#are estimates of 10,000 to 15,000 PFAS chemicals
# Out:
# 29

# %%
import plotly.express as px

contain_pfas_grouped = (
    contain_pfas
    .groupby("month")["mean_result_ngL"]
    .mean()
    .reset_index()
)

fig = px.line(
    contain_pfas_grouped,
    x="month",
    y="mean_result_ngL",
    markers=True,
    title="Average PFAS Concentration by Month"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Mean PFAS Concentration (ng/L)"
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="ffed218c-9c20-4353-80e2-8a3c942749a5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ffed218c-9c20-4353-80e2-8a3c942749a5")) {                    Plotly.newPlot(                        "ffed218c-9c20-4353-80e2-8a3c942749a5",                        [{"hovertemplate":"month=%{x}\u003cbr\u003emean_result_ngL=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2013-01-01T00:00:00.000000000","2013-02-01T00:00:00.000000000","2013-03-01T00:00:00.000000000","2013-04-01T00:00:00.000000000","2013-05-01T00:00:00.000000000","2013-06-01T00:00:00.000000000","2013-07-01T00:00:00.000000000","2013-08-01T00:00:00.000000000","2013-09-01T00:00:00.000000000","2013-10-01T00:00:00.000000000","2013-11-01T00:00:00.000000000","2013-12-01T00:00:00.000000000","2014-01-01T00:00:00.000000000","2014-02-01T00:00:00.000000000","2014-03-01T00:00:00.000000000","2014-04-01T00:00:00.000000000","2014-05-01T00:00:00.000000000","2014-06-01T00:00:00.000000000","2014-07-01T00:00:00.000000000","2014-08-01T00:00:00.000000000","2014-09-01T00:00:00.000000000","2014-10-01T00:00:00.000000000","2014-11-01T00:00:00.000000000","2014-12-01T00:00:00.000000000","2015-01-01T00:00:00.000000000","2015-02-01T00:00:00.000000000","2015-03-01T00:00:00.000000000","2015-04-01T00:00:00.000000000","2015-05-01T00:00:00.000000000","2015-06-01T00:00:00.000000000","2015-07-01T00:00:00.000000000","2015-08-01T00:00:00.000000000","2015-09-01T00:00:00.000000000","2015-10-01T00:00:00.000000000","2015-11-01T00:00:00.000000000","2015-12-01T00:00:00.000000000","2016-02-01T00:00:00.000000000","2016-10-01T00:00:00.000000000","2023-01-01T00:00:00.000000000","2023-02-01T00:00:00.000000000","2023-03-01T00:00:00.000000000","2023-04-01T00:00:00.000000000","2023-05-01T00:00:00.000000000","2023-06-01T00:00:00.000000000","2023-07-01T00:00:00.000000000","2023-08-01T00:00:00.000000000","2023-09-01T00:00:00.000000000","2023-10-01T00:00:00.000000000","2023-11-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2024-01-01T00:00:00.000000000","2024-02-01T00:00:00.000000000","2024-03-01T00:00:00.000000000","2024-04-01T00:00:00.000000000","2024-05-01T00:00:00.000000000","2024-06-01T00:00:00.000000000","2024-07-01T00:00:00.000000000","2024-08-01T00:00:00.000000000","2024-09-01T00:00:00.000000000","2024-10-01T00:00:00.000000000","2024-11-01T00:00:00.000000000","2024-12-01T00:00:00.000000000","2025-01-01T00:00:00.000000000","2025-02-01T00:00:00.000000000","2025-03-01T00:00:00.000000000","2025-04-01T00:00:00.000000000","2025-05-01T00:00:00.000000000","2025-06-01T00:00:00.000000000","2025-07-01T00:00:00.000000000","2025-08-01T00:00:00.000000000","2025-09-01T00:00:00.000000000","2025-10-01T00:00:00.000000000","2025-11-01T00:00:00.000000000","2025-12-01T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"f8","bdata":"iu1q038\u002fOUCL6Syms5g6QAAAAAAAAERAXkN5DeV9akB90+EOwV5CQA+wbPPlEE5AZ45y3TpRWkCaHgSj6YE\u002fQMCgwGfjoz9A0356PG63Q0DwCyWoNsJUQKO+s1HfGUtABvB2fa3cU0BStPzjEVhNQEdQPWMXL0ZAWOFDjml\u002fRUBhxI29UyhFQFeRQJL7EUhAwp0ZpBheRUACjkX4x8lCQIW1vlGC31NA+o5yzdOgREAv5VIuJeNPQBFnxG7XhFVAgTBnZFx1QEBdGii+B0RXQAGMOzS\u002fxkRA3xSqMM2IRUCPPxzw+ItQQLaFCkpdKztA71v8z9bYMEAQmeyrkypSQA4oE1e6B0NAgqdb88PSSkBVVVVVVRVZQNY7oghvNVhAq6qqqqqqTUAK16NwPYokQIPKO7jcYiFAkdlOCuEyGkBrd6Ur4\u002fMeQJau6q7y9xpALiScidgkGkDhkgXrzBAbQGgthUhW\u002fBpA7HaKVz19GEAIesQKy3saQEZlHN328R5AIAGtKfabHECVLer24useQBNl2cPMPBlA0ekxTvVjG0AyKhE ...

# %%
contain_pfas_grouped_all = contain_pfas.groupby('zcta').agg({"n_records": "sum", 
                                  "mean_result_ngL": "mean", 
                                  "n_detections": "sum",
                                  "pct_below_poverty": "mean",
                                  "pct_white_nh": "mean",
                                  "pct_black_nh": "mean", 
                                  "pct_asian_nh": "mean",
                                  "pct_amerind_nh": "mean",
                                  "pct_hispanic": "mean",
                                  "pct_nonwhite": "mean", 
                                  "pct_renter": "mean"}).sort_values(by="mean_result_ngL", ascending=False)
contain_pfas_grouped_all
# Out:
#        n_records  mean_result_ngL  n_detections  pct_below_poverty  \
# zcta
# 55071         58      1225.000000             2           5.270410
# 44118          6       400.000000             1          15.683206
# 55128        280       285.990556            26           6.249566
# 96950       1053       257.999126            55                NaN
# 85258         41       171.150000             9          10.801147
# ...          ...              ...           ...                ...
# 21213         87         3.000000             1          24.581831
# 30917         58         3.000000             1                NaN
# 86404         29         3.000000             1          13.284741
# 21214         87         3.000000             1          10.316219
# 21051         87         3.000000             1           0.000000
#
#        pct_white_nh  pct_black_nh  pct_asian_nh  pct_amerind_nh  pct_hispanic  \
# zcta
# 55071     77.509902      2.548648      5.579473        0.000000     11.520579
# 44118     57.107133     33.392755      3.117185        0.079229      2.059967
# 55128     66.619451      8.319226     12.855415        0.310935      6.128865
# 96950           NaN           NaN           NaN             NaN           NaN
# 85258     84.622316      2.691584      3.667137        0.082276      6.170663
# ...             ...           ...           ...             ...           ...
# 21213      5.939529     86.273807      0.218787        0.272587      4.472580
# 30917           NaN           NaN           NaN             NaN           NaN
# 86404     82.561221      0.174918      0.800382        0.376338     12.482773
# 21214     33.284809     57.717774      0.225405        0.732566      3.315332
# 21051    100.000000      0.000000      0.000000        0.000000      0.000000
#
#        pct_nonwhite  pct_renter
# zcta
# 55071     22.490098   20.428266
# 44118     42.892867   38.783410
# 55128     33.380549   22.017729
# 96950           NaN         NaN
# 85258     15.377684   26.246288
# ...             ...         ...
# 21213     94.060471   46.821759
# 30917           NaN         NaN
# 86404     17.438779   17.568328
# 21214     66.715191   21.745807
# 21051      0.000000    0.000000
#
# [9670 rows x 11 columns]

# %%
# Out:
#         zcta      month  mean_result_ngL  n_records  n_detections  n_systems  \
# 98644  96950 2015-02-01      1083.777778        132             9          1
# 98645  96950 2015-10-01       844.375000        108             8          1
# 98646  96950 2015-11-01        42.000000         24             1          1
# 98647  96950 2016-02-01        59.333333          6             3          1
# 98648  96950 2023-10-01         6.900000        261             2          1
# 98649  96950 2024-01-01         4.200000         33             1          1
# 98650  96950 2024-03-01        19.806897        431            29          1
# 98651  96950 2024-09-01         3.600000         58             2          1
#
#        n_contaminants  any_detection  ZCTA GEO_ID  ... tenure_universe  \
# 98644               6           True  <NA>   None  ...             NaN
# 98645               6           True  <NA>   None  ...             NaN
# 98646               6           True  <NA>   None  ...             NaN
# 98647               6           True  <NA>   None  ...             NaN
# 98648              29           True  <NA>   None  ...             NaN
# 98649              29           True  <NA>   None  ...             NaN
# 98650              29           True  <NA>   None  ...             NaN
# 98651              29           True  <NA>   None  ...             NaN
#
#        renter_occupied  pct_below_poverty  pct_white_nh  pct_black_nh  \
# 98644              NaN                NaN           NaN           NaN
# 98645              NaN                NaN           NaN           NaN
# 98646              NaN                NaN           NaN           NaN
# 98647              NaN                NaN           NaN           NaN
# 98648              NaN                NaN           NaN           NaN
# 98649              NaN                NaN           NaN           NaN
# 98650              NaN                NaN           NaN           NaN
# 98651              NaN                NaN           NaN           NaN
#
#        pct_asian_nh  pct_amerind_nh  pct_hispanic  pct_nonwhite  pct_renter
# 98644           NaN             NaN           NaN           NaN         NaN
# 98645           NaN             NaN           NaN           NaN         NaN
# 98646           NaN             NaN           NaN           NaN         NaN
# 98647           NaN             NaN           NaN           NaN         NaN
# 98648           NaN             NaN           NaN           NaN         NaN
# 98649           NaN             NaN           NaN           NaN         NaN
# 98650           NaN             NaN           NaN           NaN         NaN
# 98651           NaN             NaN           NaN           NaN         NaN
#
# [8 rows x 32 columns]
